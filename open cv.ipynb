# %%
import cv2
img = cv2.imread("atmiya.png",0)
#resized_image = cv2.resize(img, (650,500))
cv2.imshow("atmiya",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
img = cv2.imread("sach.jpg")
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray_img, scaleFactor = 1.05,minNeighbors=5)
for x,y,w,h in faces:
    img = cv2.rectangle(img, (x,y), (x+w,y+h),(0,255,0),3)
resized = cv2.resize(img, (500,450)) 
cv2.imshow("Gray", resized)
cv2.waitKey(2000)
cv2.destroyAllWindows()

# %%
import cv2 ,time
video = cv2.VideoCapture(0)
check,frame = video.read()
print(check)
cv2.imshow("Capturing",frame)
cv2.waitKey(500)

# print(check)
# print(frame)
# time.sleep(3)
video.release()
cv2.destroyAllWindows
# Out:
# True
# <function destroyAllWindows>

# %%
import cv2,time
video = cv2.VideoCapture(0)
a = 1
while True:
    a = a + 1
    check,frame = video.read()
    print(frame)
    gray= cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("Capturing",gray)
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
print(a)
video.release()
cv2.destroyAllWindows

# %%
import cv2,time
from datetime import datetime
import pandas

first_frame = None
video = cv2.VideoCapture(0)

while True:
    check,frame = video.read()
    print(frame)
    gray= cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray,(21,21),0)
    if first_frame is None:
        first_frame = gray
        continue
delta_frame = cv2.absdiff(first_frame,gray)
thres_delta = cv2.threshold(delta_frame, 30 , 255 , cv2.THRESH_BINART)[1]
thres_delta = cv2.dilate(thres_delta,None,iterations=0)
(_,cnts,_)= cv2.findContours(thresh_delta.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIPLE)

for contour in cnts:
    if cv2.contourArea(counter) < 1000:
        continue
    (x,y,w,h)=cv2.boundingRect(contour)
    cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),3)
    
cv2.imshow('frame',frame)
cv2.imshow('Capturing',gray)
cv2.imshow('delta',delta_frame)
cv2.imshow('thresh',thresh_delta)
key = cv2.waitKey(1)
if key == ord('q'):
    break
video.release()
cv2.destroyAllWindows

first_frame = None
status_list=[None,None]
times=[]
df = pandas.DataFrame(columns=["Start","End"])
video = cv2.VideoCapture(0)

while True:
    check,frame = video.read()
    status =0
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray,(21,21),0)
(_,cnts,_)= cv2.findContours(thresh_delta.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIPLE)

for contour in cnts:
    if cv2.contourArea(counter) < 1000:
        continue    
    status=1
    (x,y,w,h)=cv2.boundingRect(contour)
    cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),3)

status_list.append(status)

status_list = status_list[-2:]

if status_list[-1]==1 and status_list[-2:]==0:
    times.append(datetime.now())
if status_list[-1]==0 and status_list[-2:]==1:
    times.append(datetime.now())
    
print(status_list)
print(times)

for i in range(0,len(times),2):
    df=df.append({"start":times[i],"End":times[i+1]},ignore_index=True)
df.to_csv("times.csv")
video.release()
cv2.destroyAllWindows
# Out:
# [[[164 115  75]
#   [163 114  74]
#   [161 115  66]
#   ...
#   [219 219 220]
#   [218 218 219]
#   [214 214 215]]
#
#  [[161 112  70]
#   [161 112  70]
#   [155 112  65]
#   ...
#   [218 218 218]
#   [211 211 212]
#   [206 206 207]]
#
#  [[155 112  65]
#   [155 112  65]
#   [153 108  66]
#   ...
#   [211 211 212]
#   [207 207 208]
#   [207 207 208]]
#
#  ...
#
#  [[144 138 130]
#   [144 138 130]
#   [146 140 132]
#   ...
#   [ 19  13  10]
#   [ 22  16  13]
#   [ 23  17  14]]
#
#  [[143 137 129]
#   [145 139 131]
#   [146 140 132]
#   ...
#   [ 25  24  20]
#   [ 25  24  20]
#   [ 22  21  17]]
#
#  [[144 136 133]
#   [146 138 135]
#   [144 137 138]
#   ...
#   [ 28  27  23]
#   [ 28  27  23]
#   [ 26  25  21]]]
# [[[147 118  62]
#   [145 116  60]
#   [152 112  64]
#   ...
#   [222 222 223]
#   [217 221 221]
#   [213 217 217]]
#
#  [[145 116  60]
#   [146 117  61]
#   [149 115  64]
#   ...
#   [209 209 210]
#   [203 207 208]
#   [199 203 204]]
#
#  [[140 110  59]
#   [147 117  66]
# ...

# %%
import cv2,time
from datetime import datetime
import pandas

first_frame = None
status_list=[None,None]
times=[]
df = pandas.DataFrame(columns=["Start","End"])
video = cv2.VideoCapture(0)

while True:
    check,frame = video.read()
    status =0
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray,(21,21),0)
(_,cnts,_)= cv2.findContours(thresh_delta.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIPLE)

for contour in cnts:
    if cv2.contourArea(counter) < 1000:
        continue    
    status=1
    (x,y,w,h)=cv2.boundingRect(contour)
    cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),3)

status_list.append(status)

status_list = status_list[-2:]

if status_list[-1]==1 and status_list[-2:]==0:
    times.append(datetime.now())
if status_list[-1]==0 and status_list[-2:]==1:
    times.append(datetime.now())
    
print(status_list)
print(times)

for i in range(0,len(times),2):
    df=df.append({"start":times[i],"End":times[i+1]},ignore_index=True)
df.to_csv("times.csv")
video.release()
cv2.destroyAllWindows

# %% [markdown]
# # save video

# %%
import cv2
import numpy
import matplotlib

cap = cv2.VideoCapture(0)
sav = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('out.avi' , sav , 20.0 , (640,480))
while True:
    ret , frame = cap.read()
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    out.write(frame)
    cv2.imshow("frame" , frame)
    cv2.imshow("gray" , gray)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# # edit image

# %%
import cv2
import numpy
import matplotlib

img = cv2.imread("atmiya.png",1)
cv2.line(img,(0,0),(100,200),(0,0,55),1)
cv2.rectangle(img,(0,0),(50,500),(0,255,0),1)
cv2.circle(img,(100,100),50,(0,255,0),2)
ts = numpy.array([[10,20],[20,30],[30,140],[40,50]],numpy.int32)
cv2.polylines(img , [ts] , True , (255,145,214) , 5)

cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # add image part

# %%
import cv2
import numpy
import matplotlib

img = cv2.imread("atmiya.png",1)
img1 = cv2.imread("fusion.png",1)

logo = img[10:80 ,15:85]
img1[0:70 , 0:70] = logo
cv2.imshow('image',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # add image

# %%
import cv2
import numpy
import matplotlib

img = cv2.imread("atmiya.png",1)
img1 = cv2.imread("fusion.png",1)
im = cv2.resize(img, (177,177))
im1 = cv2.resize(img1, (177,177))
add = im + im1
cv2.imshow('image',add)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # threshold

# %%
import cv2
import numpy
import matplotlib

img = cv2.imread("atmiya.png",1)
retval ,thresold = cv2.threshold(img , 200 , 255 ,cv2.THRESH_BINARY)
gray_scal = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
retval2 ,thresold2 = cv2.threshold(gray_scal , 200 , 255 ,cv2.THRESH_BINARY)
gues = cv2.adaptiveThreshold(gray_scal,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C , cv2.THRESH_BINARY , 155 ,1 )

cv2.imshow('image',img)
cv2.imshow('threshold',thresold)
cv2.imshow('gray_scal',gray_scal)
cv2.imshow('gues',gues)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # color filtering

# %%
import cv2
import numpy as np
import matplotlib

cap = cv2.VideoCapture(0)
while True:
    _,frame = cap.read()
    hsv = cv2.cvtColor(frame , cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([150,150,50])
    upper_red = np.array([180,255,255])
    
    mask = cv2.inRange(hsv , lower_red , upper_red)
    res = cv2.bitwise_and(frame ,frame , mask=mask)
    
    cv2.imshow("original",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("result",res)
    
    k= cv2.waitKey(5) & 0xFF == ord('q')
    if k == 4:
        break      
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# # edge detection

# %%
import cv2
import numpy as np
import matplotlib

cap = cv2.VideoCapture(0)
while True:
    _,frame = cap.read()
    
    laplacian = cv2.Laplacian(frame , cv2.CV_64F)
    edges = cv2.Canny(frame,100,100)
    
    
    cv2.imshow('original',frame)
    cv2.imshow('laplacian',laplacian)
    cv2.imshow('edges',edges)
        
    
    k= cv2.waitKey(5) & 0xFF == ord('q')
    if k == 4:
        break 
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# # corner detection

# %%
import cv2
import numpy as np
import matplotlib

img = cv2.imread("atmiya.png",1)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

corner = cv2.goodFeaturesToTrack(gray, 500 , 0.01, 1)
corner = np.int0(corner)

for cor in corner:
    x,y = cor.ravel()
    cv2.circle(img,(x,y),3,255,-1)

cv2.imshow("corner",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # background reduction

# %%
import cv2
import numpy as np
import matplotlib

cap = cv2.VideoCapture(0)
fgbg = cv2.createBackgroundSubtractorMOG2()
while True:
    ret ,frame = cap.read()
    fgmask = fgbg.apply(frame)
    
    cv2.imshow("original",frame)
    cv2.imshow("fgmask",fgmask)
    
    k= cv2.waitKey(30) & 0xFF
    if k == 27:
        break      
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# # face & eye detection

# %%
import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
cap = cv2.VideoCapture(0)

while True:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.2, 5)

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

    cv2.imshow('img',img)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)
while True:
    ret ,frame = cap.read()
    gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray , 1.5 , 5)
    
    for (x,y,w,h) in faces:
        #print(x,y,w,h)
        roi_gray = gray[y:y+h , x:x+w]
        roi_frame = frame[y:y+h , x:x+w]
        img_item = "my img.png"
        cv2.imwrite(img_item , roi_frame)
        cv2.rectangle(frame , (x,y),(x+w,y+h) , (255,0,0) , 3)
    
    cv2.imshow("frame",frame)
    if cv2.waitKey(20) & 0XFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
for j in range(1,3):
    if j%2==0:
        print("views-row views-row-"+str(j)+" views-row-even views-row-first")
    else:
        print("views-row views-row-"+str(j)+" views-row-odd views-row-first")
    k = []
    print(type(k))
# Out:
# views-row views-row-1 views-row-odd views-row-first
# <class 'list'>
# views-row views-row-2 views-row-even views-row-first
# <class 'list'>

# %%
# from selenium import webdriver
# from bs4 import BeautifulSoup as soup
# from urllib.request import urlopen as uReq
# import pandas as pd

# filename ="orthopedic22.csv"
# f = open(filename,"a")

# headers = "Dr_name , Rate , P_name , Review\n"
# f.write(headers)

# for i in range(1,93):
#     my_url = 'https://www.scoi.com/about-us/patient-reviews?page='+str(i)
#     uClient = uReq(my_url)
#     page_html = uClient.read()
#     uClient.close()
#     page_soup = soup(page_html , "html.parser")
#     rate = []
#     rev = []
#     drname = []
#     pname = []
#     for j in range(1,11):
#         if j%2==0:
#             containers = page_soup.findAll("div",{"class":"views-row views-row-"+str(j)+" views-row-even"})
#         else:
#             containers = page_soup.findAll("div",{"class":"views-row views-row-"+str(j)+" views-row-odd"})
#         container = containers
# #         rate = page_soup.findAll("div",{"class":"views-field views-field-field-doctor-rating"})
# #         #rate.append(arate[0].text)
# #         #a = arate[0].text
# #         drname = page_soup.findAll("div",{"class":"views-field views-field-views-conditional"})
# #         #print(drname[0].text)
# #         pname = page_soup.findAll("div",{"class":"views-field views-field-field-live-review-name review-text"})
# #         #print(pname[0].text)
# #         rev = page_soup.findAll("div",{"class":"views-field views-field-nothing review-text"})
        
#         for container in containers:
#             drname_container = container.findAll("div", {"class": "views-field views-field-views-conditional"})
#             drname = drname_container[0].text.strip()

#             rating_container = container.findAll("div", {"class": "views-field views-field-field-doctor-rating"})
#             rating = rating_container[0].text
            
#             pname_container = container.findAll("div", {"class": "views-field views-field-field-live-review-name review-text"})
#             pname = pname_container[0].text
            
#             rev_container = container.findAll("div", {"class": "views-field views-field-nothing review-text"})
#             rev = rev_container[0].text
            
#             rating = rating.replace("\n","")
#             rating = rating.replace("Patient Rating: ","")
#             drname = drname.replace("Treating Doctor: ","")
#             drname = drname.replace(",",":")
#             pname = pname.replace("–","")
#             rev = rev.replace(",",":")
#             rev = rev.replace("\n"," ")
            
            
            
# #             print(drname)
# #             print(rating)
# #             print(pname)
            
            
#             f.write(drname +  "," +rating + "," + pname +  "\n")
# f.close()
